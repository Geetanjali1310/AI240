# %% [markdown]
# # Seaborn Exercise  AI240 - 10459
# # Instructor - Dr. Uma Gajendragadkar
#
# We are going to use iris dataset to learn Seaborn Library
# # Exercise 1 -
#
# Install Seaborn library with below command
#
# !pip install seaborn
#
# Import seaborn library with below command and load iris dataset and check top few rows of the data
#
# from matplotlib import pyplot as plt
#
# %matplotlib inline
#
# import seaborn as sns
#
# iris = sns.load_dataset('iris')
#
# iris.head()

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\smita\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\smita\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\smita\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\smita\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smita\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smita\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smita\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\smita\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Exercise 2 - Draw a pairplot
# Look at the output generated in Exercise 1.
# Each row of the data represents a single observed flower and the number of rows represents the total number of flowers in the dataset. The rows of the matrix are called as samples. The columns of the matrix are called as features.
#
# From iris dataset we predict the species of flower based on the other measurements. In this case, the Species column would be considered as the feature.
# Execute below lines of code and check the output
#
# iris = sns.load_dataset('iris')
#
# sns.pairplot(iris, hue='species', height=3)

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue='species', height=3)

# %%
plt.show()

# %% [markdown]
# # Exercise 3 - Draw a boxplot
#
# plt.figure(figsize=(10,8))
#
# sns.boxplot(data=iris)

# %%
plt.figure(figsize=(10,8))

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %%
plt.show()

# %% [markdown]
# # Exercise 4 - Draw a violin plot
#
# species_colors = ['#78C850',  # Setosa
#                     '#F08030',  # Versicolor
#                     '#6890F0',  # Verginica
#                   ]
#
# sns.violinplot( data=iris, palette=species_colors)

# %%
species_colors = ['#78C850', '#F08030', '#6890F0']

# %%
sns.violinplot(x='species', y='sepal_length', data=iris, hue='species', palette=species_colors, legend=False)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
plt.show()

# %% [markdown]
# # Exercise 5 - Draw a Histogram
#  Histogram
# A histogram is a bar graph-like representation of data that buckets a range of classes into columns along the horizontal x-axis.
#
# 1)
#
# sns.histplot(iris, x='petal_length', kde=True)
#
# 2) Also try below code with another dataset
#
# penguins = sns.load_dataset("penguins")
#
# sns.histplot(data=penguins, x="flipper_length_mm")

# %%
sns.histplot(iris, x='petal_length', kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
plt.show()

# %% [markdown]
# ### Trying the code with the penguin dataset:

# %%
penguins = sns.load_dataset("penguins")

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
plt.show()

# %% [markdown]
# # Exercise 6 - Draw a Swarm Plot
#
# A swarm plot is another way of plotting the distribution of an attribute or the joint distribution of a couple of attributes.
#
# Create a Swarm plot of Petal length across the species.
#
# sns.swarmplot(y='petal_length', x='species', data=iris, palette=species_colors)

# %%
sns.swarmplot(y='petal_length', x='species', data=iris, hue='species', palette=species_colors, legend=False, size=4)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
plt.show()

# %% [markdown]
# # Exercise 7 - Draw a Bar Plot
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.
# Execute below command
#
# sns.barplot(penguins, x="island", y="body_mass_g")

# %%
sns.barplot(penguins, x="island", y="body_mass_g")
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
plt.show()

# %% [markdown]
# # Exercise 8 - Draw a Heatmap Plot
#
# corrmat = iris.corr()
#
# sns.heatmap(corrmat, annot = True, square = True)

# %%
# Calculate the correlation matrix
corrmat = iris.iloc[:, :-1].corr() 

# Plot heatmap
sns.heatmap(corrmat, annot=True, square=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Iris Features")
plt.show()
